# %%
# %run Paywall-Utils.ipynb
# Out:
# Automatically created module for IPython interactive environment
# (10346,) (1826,) (10346,) (1826,)

# %%
X_sequences_matrix_pos, X_embeded_matrix_pos, Y_pos, x_sequences_matrix_pos, x_embeded_matrix_pos, y_pos, tok_pos = get_pos_matrix()

t = get_tsne_matrix(X_sequences_matrix_pos, dim=2)
# Out:
# (8632,) (1524,) (8632,) (1524,)
# T-Sne done---------

# %%
mu, sigma = GaussianEstimation.estimateGaussian(t)
GaussianEstimation.visualize(t, Y_pos,  mu, sigma, h=1)
# Out:
# shapes :  (2,) (2, 2)
# Shapes :  (172, 171) (172, 171) (29412, 2)
# Z.shape (172, 171)
# X.shape (8632, 2)

# %%
mu, sigma = GaussianEstimation.estimateGaussian(X_embeded_matrix_pos)
pval = GaussianEstimation.multivariateGaussian(X_embeded_matrix_pos, mu, sigma)
# Out:
# shapes :  (4137,) (4137, 4137)
# /opt/conda/Conda/lib/python3.6/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
# /opt/conda/Conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in double_scalars
